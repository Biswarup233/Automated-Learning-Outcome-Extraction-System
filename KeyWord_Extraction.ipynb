# %% [markdown]
# # Key Word Extraction from Text
#
#
# ---

# %%
# %pip install docx2txt
import docx2txt
Text = docx2txt.process("SW engg -B.tech syllabus.docx")
print(Text)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Name of the course
#
# Software Engineering
#
# Course Code: PEC(IT)602A
#
# Semester: 6th
#
# Duration: 6 months
#
# Maximum Marks: 100
#
#
#
#
#
# Teaching Scheme
#
# Examination Scheme
#
# Theory:   3 hrs/week
#
# Mid Term I Exam:                                        15 Marks
#
# Credit Points: 3
#
# Mid Term II Exam:                                       15 Marks
#
#
#
# Class performance & Attendance:           20 Marks
#
#
#
# End Semester Exam & Viva:                      50 Marks
#
#
#
#
#
# Objective:
#
#
#
# 1.
#
# To understand different software process models.
#
# 2.
#
# To analyze software testing activities.
#
# 3.
#
# To determine software reliability and quality.
#
# 4.
#
# To assess different tools for software project management.
#
# Pre-Requisite:
#
#
#
# 1.
#
# Data Structures & Algorithms -PC(CS/IT)302
#
# 2.
#
# Mathematics III-BS(CS/IT)307
#
# Unit
#
# Content
#
# Hrs
#
# Marks
#
# 1
#
# ...

# %%
TextOne=Text.split("Content",1)[1]

# %%
TextT=TextOne.split("Course Outcome:",1)[0]

# %%
Text=TextT

# %%
import nltk
from nltk import word_tokenize
import string

nltk.download('punkt')

def clean(text):
    text = text.lower()
    printable = set(string.printable)
    text = filter(lambda x: x in printable, text)
    text = "".join(list(text))
    return text

Cleaned_text = clean(Text)
print(Cleaned_text)
text = word_tokenize(Cleaned_text)

print ("Tokenized Text: \n")
print (text)
# Out:
# hrs
#
# marks
#
# 1
#
# information system:
#
# software engineering objectives, definitions, software development life cycle, software process models  waterfall model, spiral model, agile model. software requirements (srs), feasibility analysis.
#
# 6
#
#
#
# 2
#
# software design:
#
# context diagram and dfd, physical and logical dfds, data dictionary, er diagrams, decision tree, decision table and structure chart, structured english.
#
# 4
#
#
#
# 3
#
# software testing:
#
#  levels of testing, white-box and black-box testing, test case
#
# generation, acceptance testing, software validation, regression testing, mutation analysis, cyclomatic complexity.
#
# 10
#
#
#
# 4
#
# reliability:
#
# reliability concept, software reliability, hazard, mttf, mtbf, repair and availability.
#
# 4
#
#
#
# 5
#
# software quality:
#
#  quality attributes, risk management, mccalls quality factors, software quality assurance, quality standards, total quality management.
#
# 4
#
#
#
# 6
#
# ...

# %% [markdown]
# ## Groping with POS TAG
# ---
# ### List of POS_TAGS in NLTK
# ![pos tags.png](data:image/png;base64,...)

# %%
nltk.download('averaged_perceptron_tagger')
  
POS_tag = nltk.pos_tag(text)

print ("Tokenized Text with POS tags: \n")
print (POS_tag)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\banty\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Tokenized Text with POS tags:
#
# ...

# %% [markdown]
# ## Using Wordnet Lemmatizing of a text
# ----
# The WordNet is a part of Python's Natural Language Toolkit. It is a large word database of English Nouns, Adjectives, Adverbs and Verbs. These are grouped into some set of cognitive synonyms, which are called synsets.
#
# To use the Wordnet, at first we have to install the NLTK module, then download the WordNet package.
#
# ### Lemmatization:
# ---
# Lemmatization usually refers to doing things properly with the use of a vocabulary and morphological analysis of words, normally aiming to remove inflectional endings only and to return the base or dictionary form of a word, which is known as the lemma

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer

wordnet_lemmatizer = WordNetLemmatizer()

adjective_tags = ['JJ','JJR','JJS']

lemmatized_text = []

for word in POS_tag:
    if word[1] in adjective_tags:
        lemmatized_text.append(str(wordnet_lemmatizer.lemmatize(word[0],pos="a")))
    else:
        lemmatized_text.append(str(wordnet_lemmatizer.lemmatize(word[0]))) #default POS = noun
        
print ("Text tokens after lemmatization of adjectives and nouns: \n")
print (lemmatized_text)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\banty\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\banty\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Text tokens after lemmatization of adjectives and nouns:
#
# ...

# %%
lemmatized_text=lemmatized_text[2:]

# %%
POS_tag = nltk.pos_tag(lemmatized_text)

print ("Lemmatized text with POS tags: \n")
print (POS_tag)
# Out:
# Lemmatized text with POS tags:
#
# ...

# %% [markdown]
# ## Get Rid Off from STOP WORDS
# ---------

# %%
stopwords = []

wanted_POS = ['NN','NNS','NNP','NNPS','JJ','JJR','JJS','VBG','FW'] 

for word in POS_tag:
    if word[1] not in wanted_POS:
        stopwords.append(word[0])

punctuations = list(str(string.punctuation))

stopwords = stopwords + punctuations

# %%
stopword_file = open("long_stopwords.txt", "r")

lots_of_stopwords = []

for line in stopword_file.readlines():
    lots_of_stopwords.append(str(line.strip()))

stopwords_plus = []
stopwords_plus = stopwords + lots_of_stopwords
stopwords_plus = set(stopwords_plus)

#Stopwords_plus contain total set of all stopwords

# %%
processed_text = []
for word in lemmatized_text:
    if word not in stopwords_plus:
        processed_text.append(word)
print (processed_text)
# Out:
# ['information', 'system', 'software', 'engineering', 'objective', 'definition', 'software', 'development', 'life', 'cycle', 'software', 'process', 'model', 'waterfall', 'model', 'spiral', 'model', 'agile', 'model', 'software', 'requirement', 'sr', 'feasibility', 'analysis', 'software', 'design', 'context', 'diagram', 'dfd', 'physical', 'logical', 'dfds', 'data', 'dictionary', 'er', 'diagram', 'decision', 'tree', 'decision', 'table', 'structure', 'chart', 'english', 'software', 'testing', 'level', 'testing', 'white-box', 'black-box', 'testing', 'test', 'case', 'generation', 'acceptance', 'testing', 'software', 'validation', 'regression', 'testing', 'mutation', 'analysis', 'cyclomatic', 'complexity', 'reliability', 'reliability', 'concept', 'software', 'reliability', 'hazard', 'mttf', 'mtbf', 'repair', 'availability', 'software', 'quality', 'quality', 'attribute', 'risk', 'management', 'quality', 'factor', 'software', 'quality', 'assurance', 'quality', 'standard', 'total', 'quality', '
# ...

# %%
vocabulary = list(set(processed_text))
print (vocabulary)
# Out:
# ['pert', 'scheduling', 'test', 'objective', 'tree', 'planning', 'complexity', 'design', 'analysis', 'life', 'dfd', 'management', 'process', 'definition', 'agile', 'system', 'decision', 'mttf', 'diagram', 'software', 'function', 'cost', 'feasibility', 'context', 'level', 'generation', 'reliability', 'mtbf', 'logical', 'total', 'path', 'structure', 'hazard', 'halstead', 'waterfall', 'model', 'information', 'chart', 'mutation', 'point', 'development', 'case', 'assurance', 'quality', 'sr', 'risk', 'data', 'metric', 'project', 'wb', 'dfds', 'availability', 'black-box', 'testing', 'er', 'attribute', 'english', 'method', 'estimation-cocomo', 'gantt', 'cyclomatic', 'concept', 'standard', 'spiral', 'repair', 'critical', 'engineering', 'physical', 'regression', 'factor', 'tools-', 'requirement', 'dictionary', 'validation', 'white-box', 'cycle', 'configuration', 'table', 'acceptance']

# %%
import numpy as np
import math
vocab_len = len(vocabulary)

weighted_edge = np.zeros((vocab_len,vocab_len),dtype=np.float32)

score = np.zeros((vocab_len),dtype=np.float32)
window_size = 3
covered_coocurrences = []

for i in range(0,vocab_len):
    score[i]=1
    for j in range(0,vocab_len):
        if j==i:
            weighted_edge[i][j]=0
        else:
            for window_start in range(0,(len(processed_text)-window_size)):
                
                window_end = window_start+window_size
                
                window = processed_text[window_start:window_end]
                
                if (vocabulary[i] in window) and (vocabulary[j] in window):
                    
                    index_of_i = window_start + window.index(vocabulary[i])
                    index_of_j = window_start + window.index(vocabulary[j])
                    
                    # index_of_x is the absolute position of the xth term in the window 
                    # (counting from 0) 
                    # in the processed_text
                      
                    if [index_of_i,index_of_j] not in covered_coocurrences:
                        weighted_edge[i][j]+=1/math.fabs(index_of_i-index_of_j)
                        covered_coocurrences.append([index_of_i,index_of_j])

# %%
inout = np.zeros((vocab_len),dtype=np.float32)

for i in range(0,vocab_len):
    for j in range(0,vocab_len):
        inout[i]+=weighted_edge[i][j]

# %%
MAX_ITERATIONS = 50
d=0.85
threshold = 0.0001 #convergence threshold

for iter in range(0,MAX_ITERATIONS):
    prev_score = np.copy(score)
    
    for i in range(0,vocab_len):
        
        summation = 0
        for j in range(0,vocab_len):
            if weighted_edge[i][j] != 0:
                summation += (weighted_edge[i][j]/inout[j])*score[j]
                
        score[i] = (1-d) + d*(summation)
    
    if np.sum(np.fabs(prev_score-score)) <= threshold: #convergence condition
        print("Converging at iteration "+str(iter)+"....")
        break
# Out:
# Converging at iteration 31....

# %%
for i in range(0,vocab_len):
    print("Score of "+vocabulary[i]+": "+str(score[i]))
# Out:
# Score of pert: 0.9375159
# Score of scheduling: 0.6660449
# Score of test: 0.76491046
# Score of objective: 0.7353449
# Score of tree: 0.8268492
# Score of planning: 0.65088075
# Score of complexity: 0.6475755
# Score of design: 0.74480104
# Score of analysis: 1.9850708
# Score of life: 0.72832835
# Score of dfd: 0.8693534
# Score of management: 2.8465717
# Score of process: 0.6972628
# Score of definition: 0.7335813
# Score of agile: 0.6896216
# Score of system: 0.68626535
# Score of decision: 1.3166604
# Score of mttf: 0.80345696
# Score of diagram: 1.5677364
# Score of software: 7.5340266
# Score of function: 0.7853268
# Score of cost: 0.73691374
# Score of feasibility: 0.7313607
# Score of context: 0.7894492
# Score of level: 0.6935469
# Score of generation: 0.7804035
# Score of reliability: 1.4519066
# Score of mtbf: 0.81274015
# Score of logical: 0.9212137
# Score of total: 0.66283095
# Score of path: 0.57158077
# Score of structure: 0.82286805
# Score of hazard: 0.76581687
# ...

# %%
phrases = []

phrase = " "
for word in lemmatized_text:
    
    if word in stopwords_plus:
        if phrase!= " ":
            phrases.append(str(phrase).strip().split())
        phrase = " "
    elif word not in stopwords_plus:
        phrase+=str(word)
        phrase+=" "

print("Partitioned Phrases (Candidate Keyphrases): \n")
print(phrases)
# Out:
# Partitioned Phrases (Candidate Keyphrases):
#
# ...

# %%
unique_phrases = []

for phrase in phrases:
    if phrase not in unique_phrases:
        unique_phrases.append(phrase)

print("Unique Phrases (Candidate Keyphrases): \n")
print(unique_phrases)
# Out:
# Unique Phrases (Candidate Keyphrases):
#
# ...

# %%
for word in vocabulary:
    #print word
    for phrase in unique_phrases:
        if (word in phrase) and ([word] in unique_phrases) and (len(phrase)>1):
            #if len(phrase)>1 then the current phrase is multi-worded.
            #if the word in vocabulary is present in unique_phrases as a single-word-phrase
            # and at the same time present as a word within a multi-worded phrase,
            # then I will remove the single-word-phrase from the list.
            unique_phrases.remove([word])
            
print("Thinned Unique Phrases (Candidate Keyphrases): \n")
print(unique_phrases)
# Out:
# Thinned Unique Phrases (Candidate Keyphrases):
#
# ...

# %%
phrase_scores = []
keywords = []
for phrase in unique_phrases:
    phrase_score=0
    keyword = ''
    for word in phrase:
        keyword += str(word)
        keyword += " "
        phrase_score+=score[vocabulary.index(word)]
    phrase_scores.append(phrase_score)
    keywords.append(keyword.strip())

i=0
for keyword in keywords:
    print ("Keyword: '"+str(keyword)+"', Score: "+str(phrase_scores[i]))
    i+=1
# Out:
# Keyword: 'information system', Score: 1.1527633965015411
# Keyword: 'software engineering objective', Score: 9.014644026756287
# Keyword: 'definition', Score: 0.7335813045501709
# Keyword: 'software development life cycle', Score: 9.716444790363312
# Keyword: 'software process model waterfall model', Score: 12.713129997253418
# Keyword: 'spiral model', Score: 2.5925880074501038
# Keyword: 'agile model', Score: 2.5779256224632263
# Keyword: 'software requirement', Score: 8.252124726772308
# Keyword: 'sr', Score: 0.7375874519348145
# Keyword: 'feasibility analysis', Score: 2.716431498527527
# Keyword: 'software design', Score: 8.278827667236328
# Keyword: 'context diagram', Score: 2.3571856021881104
# Keyword: 'dfd', Score: 0.8693534135818481
# Keyword: 'physical', Score: 0.8996924161911011
# Keyword: 'logical dfds', Score: 1.8481573462486267
# Keyword: 'data dictionary', Score: 1.82095468044281
# Keyword: 'er diagram', Score: 2.4371780157089233
# ...

# %%
print(keywords)
# Out:
# ['information system', 'software engineering objective', 'definition', 'software development life cycle', 'software process model waterfall model', 'spiral model', 'agile model', 'software requirement', 'sr', 'feasibility analysis', 'software design', 'context diagram', 'dfd', 'physical', 'logical dfds', 'data dictionary', 'er diagram', 'decision tree', 'decision table', 'structure chart', 'english', 'software testing', 'level', 'white-box', 'black-box testing', 'test case generation', 'acceptance testing', 'software validation', 'regression testing', 'mutation analysis', 'cyclomatic complexity', 'reliability concept', 'software reliability', 'hazard', 'mttf', 'mtbf', 'repair', 'availability', 'software quality', 'quality attribute', 'risk management', 'quality factor', 'software quality assurance', 'quality standard', 'total quality management', 'software project management', 'software project planning', 'project scheduling', 'software configuration management', 'cost estimation-coc
# ...

# %% [markdown]
# # keyword to sentence #

# %%
import random
random_bloomsLevel=[]
# A list of keywords
keywords

# A list of action verbs corresponding to different levels of Bloom's Taxonomy
verbs = ['list', 'name', 'define', 'identify', 'explain', 'summarize', 'paraphrase', 'interpret', 'apply', 'demonstrate', 'use', 'illustrate', 'analyze', 'compare', 'contrast', 'differentiate', 'evaluate', 'judge', 'assess', 'critique', 'create', 'design', 'develop', 'generate']
#print("Sentences using Bloom's Taxonomy and Keywords using randomized approach :\n")
for keyword in keywords:
    verb = random.choice(verbs)
    sentence = f'{verb}ing  {keyword} .'
    random_bloomsLevel.append(sentence)

# %%
import requests
bert_sentences=[]
keywords
url = "https://bloom-bert-api-dmkyqqzsta-as.a.run.app/predict"
for keyword in keywords:
    
    data = {"text": keyword}
    response = requests.post(url, json=data)
    data=response.json()['blooms_level']
    sentence = f'{data} {keyword} .'
    bert_sentences.append(sentence)

# %%
import requests
chatgpt_BloomsLevel=[]
myurl = "https://api.openai.com/v1/engines/text-davinci-003/completions"
api_key = "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"
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_key}"
}
for keyword in keywords:
  data = {
    "prompt": f'what is the blooms level of the topic {keyword} say in single word proper verb without punctuation',
    "temperature": 0.5,
    "max_tokens": 1000
    }
  response = requests.post(myurl, headers=headers, json=data)
  level=response.json()['choices'][0]['text'] 
  sentence= f'{level} {keyword}'
  sentence=sentence.replace('\n\n', '')
  chatgpt_BloomsLevel.append(sentence)

# %%
keywords.insert(0,'TOPICS')
random_bloomsLevel.insert(0,'Blooms  Level by RANDOM METHOD')
bert_sentences.insert(0,"Blooms  Level by BERT MODEL")
chatgpt_BloomsLevel.insert(0,"Blooms  Level by CHATGPT")
arr1=keywords
arr2=random_bloomsLevel
arr3=bert_sentences
arr4=chatgpt_BloomsLevel
max_len_arr1 = max([len(s) for s in arr1])
max_len_arr2 = max([len(s) for s in arr2])
max_len_arr3 = max([len(s) for s in arr3])
max_len_arr4 = max([len(s) for s in arr4])
length = 10
char = '-'
line = char * (max_len_arr1+max_len_arr2+max_len_arr3+max_len_arr4+14)
line1= char*(max_len_arr1+max_len_arr2)
line2= char*(max_len_arr1+max_len_arr3)
line3= char*(max_len_arr1+max_len_arr4)

# %%
print("-------------------Random Method--------------------\n\n")

for i in range(len(arr1)):
    print(f"|{arr1[i]:<{max_len_arr1}}\t | {arr2[i]:<{max_len_arr2}}\t ")
    print(line1)
# Out:
# -------------------Random Method--------------------
#
#
# |TOPICS                                	 | Blooms  Level by RANDOM METHOD
# --------------------------------------------------------------------------------------------
# |information system                    	 | designing  information system .
# --------------------------------------------------------------------------------------------
# |software engineering objective        	 | evaluateing  software engineering objective .
# --------------------------------------------------------------------------------------------
# |definition                            	 | interpreting  definition .
# --------------------------------------------------------------------------------------------
# |software development life cycle       	 | defineing  software development life cycle .
# --------------------------------------------------------------------------------------------
# ...

# %%
print("-------------------Bert Model--------------------\n\n")

for i in range(len(arr1)):
    print(f"|{arr1[i]:<{max_len_arr1}}\t | {arr3[i]:<{max_len_arr3}}\t ")
    print(line2)
# Out:
# -------------------Bert Model--------------------
#
#
# |TOPICS                                	 | Blooms  Level by BERT MODEL
# -----------------------------------------------------------------------------------------
# |information system                    	 | Remember information system .
# -----------------------------------------------------------------------------------------
# |software engineering objective        	 | Apply software engineering objective .
# -----------------------------------------------------------------------------------------
# |definition                            	 | Remember definition .
# -----------------------------------------------------------------------------------------
# |software development life cycle       	 | Remember software development life cycle .
# -----------------------------------------------------------------------------------------
# |software process model waterfall model	 | Understand software process model waterfall model .
# ...

# %%
print("-------------------Chatgpt--------------------\n\n")

for i in range(len(arr1)):
    print(f"|{arr1[i]:<{max_len_arr1}}\t | {arr4[i]:<{max_len_arr4}}\t")
    print(line3)
# Out:
# -------------------Chatgpt--------------------
#
#
# |TOPICS                                	 | Blooms  Level by CHATGPT
# ------------------------------------------------------------------------------------
# |information system                    	 | Analyze information system
# ------------------------------------------------------------------------------------
# |software engineering objective        	 | Synthesize software engineering objective
# ------------------------------------------------------------------------------------
# |definition                            	 | Explain definition
# ------------------------------------------------------------------------------------
# |software development life cycle       	 | Analyze software development life cycle
# ------------------------------------------------------------------------------------
# |software process model waterfall model	 | Analyze software process model waterfall model
# ...

# %%
print(line)

for i in range(len(arr1)):
    print(f"| {arr1[i]:<{max_len_arr1}}\t | {arr2[i]:<{max_len_arr2}}\t | {arr3[i]:<{max_len_arr3}}\t | {arr4[i]:<{max_len_arr4}}")
    print(line)
# Out:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# | TOPICS                                	 | Blooms  Level by RANDOM METHOD                        	 | Blooms  Level by BERT MODEL                        	 | Blooms  Level by CHATGPT
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# | information system                    	 | designing  information system .                       	 | Remember information system .                      	 | Analyze information system
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...
